# %%
print("Hi welcome to the session")
# Out:
# Hi welcome to the session

# %%
Name = "Anu"
print("My Name is" , Name)
# Out:
# My Name is Anu

# %%
print("Thank you for your session.It is very helpfull")
# Out:
# Thank you for your session.It is very helpfull
