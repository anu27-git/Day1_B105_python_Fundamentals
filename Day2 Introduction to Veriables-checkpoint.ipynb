# %%
a=10
b= 5 
c=a+b
print(c)
# Out:
# 15

# %%
Fullname = "anu siva"
Secondname = 'Roopa'
print(Fullname)
print(Fullname.title())
print(Fullname.lower())
print(Fullname.upper())
print(Secondname)
# Out:
# anu siva
# Anu Siva
# anu siva
# ANU SIVA
# Roopa
